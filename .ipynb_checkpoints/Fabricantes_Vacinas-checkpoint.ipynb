# %% [markdown]
# # Importações

# %%
# Importação das bibliotecas
import pandas as pd
import matplotlib
import seaborn as sns

# %%
# Importação do banco de dados CSV
dados = pd.read_csv(r'C:\Users\Usuário\Documents\GitHub\Analise_Dados\DadosVacinaAM.csv', sep=";")
# Out:
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_7476\3544363823.py:2: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   dados = pd.read_csv(r'C:\Users\Usuário\Documents\GitHub\Analise_Dados\DadosVacinaAM.csv', sep=";")

# %%
dados.head()
# Out:
#                                  document_id  \
# 0  2ff5a507-3952-495f-9ca8-c54baf691189-i0b0
# 1  6164349f-88aa-417e-bff0-cd131003e374-i0b0
# 2  2ff8e060-dc28-45f6-b6f1-1169b98d859b-i0b0
# 3  616bfad4-77e7-462f-a02b-9c78e9985699-i0b0
# 4  2ffea5ee-d722-4914-803d-eb6a03ce5ef2-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  5e33933ed97829c5db51bde5e9b7009e4e433ca19eca62...            29.0
# 1  4151d672775a8d4bb838ed5f645bc84bfc8d03f51212f0...            13.0
# 2  b3474170901420e61a7b30753bd86ba71acf1135f6935b...            77.0
# 3  981e37118128c0523cf63422aef1216e3ab91b59ff71b4...            66.0
# 4  ceb233a69e1b90d14ab1808fb6d3da4d3dc61fb67419ee...            31.0
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1992-07-02                          F                      4.0
# 1              2007-09-10                          F                      3.0
# 2              1944-01-25                          F                     99.0
# 3              1954-08-25                          M                      1.0
# 4              1989-10-12                          M                      3.0
#
#   paciente_racaCor_valor paciente_endereco_coIbgeMunicipio  \
# 0                AMARELA                            130260
# 1                  PARDA                            130260
# 2         SEM INFORMACAO                            130260
# 3                 BRANCA                            130260
# 4                  PARDA                            130260
#
#   paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                       10                        MANAUS  ...
# 1                       10                        MANAUS  ...
# 2                       10                        MANAUS  ...
# 3                       10                        MANAUS  ...
# 4                       10                        MANAUS  ...
#
#   vacina_categoria_codigo vacina_categoria_nome vacina_lote  \
# 0                     2.0          Faixa Etária      FF8848
# 1                     2.0          Faixa Etária      FD7209
# 2                     2.0          Faixa Etária    4120Z005
# 3                     2.0          Faixa Etária    4120Z025
# 4                     2.0          Faixa Etária      210277
#
#   vacina_fabricante_nome  vacina_fabricante_referencia vacina_dataAplicacao  \
# 0                 PFIZER                           NaN           2021-10-21
# 1                 PFIZER                           NaN           2021-08-27
# 2    ASTRAZENECA/FIOCRUZ                           NaN           2021-02-05
# 3    ASTRAZENECA/FIOCRUZ                           NaN           2021-03-05
# 4       SINOVAC/BUTANTAN                           NaN           2021-08-02
#
#   vacina_descricao_dose  vacina_codigo  \
# 0               1ª Dose             87
# 1               1ª Dose             87
# 2               1ª Dose             85
# 3               1ª Dose             85
# 4               2ª Dose             86
#
#                                  vacina_nome sistema_origem
# 0                COVID-19 PFIZER - COMIRNATY            SMV
# 1                COVID-19 PFIZER - COMIRNATY            SMV
# 2  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD            SMV
# 3  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD            SMV
# 4      COVID-19 SINOVAC/BUTANTAN - CORONAVAC            SMV
#
# [5 rows x 32 columns]

# %%
# Listagem das colunas para consulta
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1708357 entries, 0 to 1708356
# Data columns (total 32 columns):
#  #   Column                                    Dtype
# ---  ------                                    -----
#  0   document_id                               object
#  1   paciente_id                               object
#  2   paciente_idade                            float64
#  3   paciente_dataNascimento                   object
#  4   paciente_enumSexoBiologico                object
#  5   paciente_racaCor_codigo                   float64
#  6   paciente_racaCor_valor                    object
#  7   paciente_endereco_coIbgeMunicipio         object
#  8   paciente_endereco_coPais                  object
#  9   paciente_endereco_nmMunicipio             object
#  10  paciente_endereco_nmPais                  object
#  11  paciente_endereco_uf                      object
#  12  paciente_endereco_cep                     object
#  13  paciente_nacionalidade_enumNacionalidade  object
#  14  estabelecimento_valor                     int64
#  15  estabelecimento_razaoSocial               object
#  16  estalecimento_noFantasia                  object
#  17  estabelecimento_municipio_codigo          int64
#  18  estabelecimento_municipio_nome            object
#  19  estabelecimento_uf                        object
#  20  vacina_grupoAtendimento_codigo            float64
#  21  vacina_grupoAtendimento_nome              object
#  22  vacina_categoria_codigo                   float64
#  23  vacina_categoria_nome                     object
#  24  vacina_lote                               object
#  25  vacina_fabricante_nome                    object
#  26  vacina_fabricante_referencia              object
#  27  vacina_dataAplicacao                      object
#  28  vacina_descricao_dose                     object
#  29  vacina_codigo                             int64
#  30  vacina_nome                               object
#  31  sistema_origem                            object
# dtypes: float64(4), int64(3), object(25)
# memory usage: 417.1+ MB

# %%
dados['vacina_dataAplicacao'] = pd.to_datetime(dados['vacina_dataAplicacao'], format='%Y-%m-%d')
dados_primeira_dose = dados.loc[dados['vacina_descricao_dose'] == '1ª Dose']
dados_primeira_dose.sort_values('vacina_dataAplicacao', ascending= False)
# Out:
#                                        document_id  \
# 1695228  c3282107-2e44-4b6a-a2e5-78309b252e58-i0b0
# 1139646  b7d8e39f-77a7-4836-9868-c4d21597e7b9-i0b0
# 1197949  6f1a9c4e-1f31-45e5-bc9a-297f0c5eb4b9-i0b0
# 977036   6bc7f48d-ffa8-4cfc-8543-db9ab2ed81a8-i0b0
# 591481   f8fd8f8d-04fd-4a9f-b78c-77650620ae04-i0b0
# ...                                            ...
# 1429293  198c9f1c-cc1b-4441-b46a-e8bb52fd611b-i0b0
# 1009293  6da07a74-3683-473e-b7ce-ce13144f548c-i0b0
# 715583   6a5f43c8-db24-4f6d-8d86-f6515d489ff0-i0b0
# 1431741  47646262-e40b-44cf-b491-cf01aee88149-i0b0
# 1391075  3f3f2a11-2739-44bf-9d13-3ee5747abee0-i0b0
#
#                                                paciente_id  paciente_idade  \
# 1695228  f0bb74f9f946be5c434d662229ea63d15be4412eecd262...             2.0
# 1139646  d1670ad857751c1cc865e5f64e453fb5ba803449eaae37...             4.0
# 1197949  79df0389c84f68f2c64c6697e1a587b6ad515376512676...             2.0
# 977036   73b63994c129c38f17c94f0f85daecb3516e72664d232e...             1.0
# 591481   0c675598d0a8d539093bb17e08edda2354f417ee213536...             2.0
# ...                                                    ...             ...
# 1429293  b33ab4e0379b4c9c3a7078f9860d568938c48cd7dc2921...            34.0
# 1009293  4341fe254b44dce18a7554d2e7b36f6d0eda21297da154...            77.0
# 715583   92b133ed5c07fcfbf0d401d4abf37ed0bd17cd7a2d734c...            84.0
# 1431741  adc68c1a028ef4cb42d05ab2637044dce8a73397c46898...            79.0
# 1391075  63199300f0af650b3f853f25aa4ee61838beeb9a21bb21...            71.0
#
#         paciente_dataNascimento paciente_enumSexoBiologico  \
# 1695228              2020-11-11                          F
# 1139646              2019-02-01                          F
# 1197949              2020-04-12                          M
# 977036               2021-03-16                          F
# 591481               2020-04-26                          M
# ...                         ...                        ...
# 1429293              1986-11-09                          F
# 1009293              1943-05-24                          M
# 715583               1936-05-08                          M
# 1431741              1941-07-09                          M
# 1391075              1949-07-22                          M
#
#          paciente_racaCor_codigo paciente_racaCor_valor  \
# 1695228                      3.0                  PARDA
# 1139646                     99.0         SEM INFORMACAO
# 1197949                      3.0                  PARDA
# 977036                       3.0                  PARDA
# 591481                       3.0                  PARDA
# ...                          ...                    ...
# 1429293                      3.0                  PARDA
# 1009293                      3.0                  PARDA
# 715583                       4.0                AMARELA
# 1431741                      4.0                AMARELA
# 1391075                      4.0                AMARELA
#
#         paciente_endereco_coIbgeMunicipio paciente_endereco_coPais  \
# 1695228                          130050.0                     10.0
# 1139646                          130063.0                     10.0
# 1197949                            130340                       10
# 977036                             130050                       10
# 591481                             130420                       10
# ...                                   ...                      ...
# 1429293                            130260                       10
# 1009293                            130260                       10
# 715583                             130120                       10
# 1431741                            130120                       10
# 1391075                            130120                       10
#
#         paciente_endereco_nmMunicipio  ... vacina_categoria_codigo  \
# 1695228                   BARREIRINHA  ...                     2.0
# 1139646                        BERURI  ...                     2.0
# 1197949                     PARINTINS  ...                     2.0
# 977036                    BARREIRINHA  ...                     2.0
# 591481                           TEFE  ...                     2.0
# ...                               ...  ...                     ...
# 1429293                        MANAUS  ...                     9.0
# 1009293                        MANAUS  ...                     NaN
# 715583                          COARI  ...                     NaN
# 1431741                         COARI  ...                     NaN
# 1391075                         COARI  ...                     NaN
#
#           vacina_categoria_nome vacina_lote  \
# 1695228            Faixa Etária      GC9016
# 1139646            Faixa Etária      220299
# 1197949            Faixa Etária      GC9016
# 977036             Faixa Etária      GC9016
# 591481             Faixa Etária      GC9016
# ...                         ...         ...
# 1429293  Trabalhadores de Saúde   202010028
# 1009293                     NaN    4120Z005
# 715583                      NaN    4120Z005
# 1431741                     NaN    4120Z005
# 1391075                     NaN    4120Z005
#
#                       vacina_fabricante_nome  vacina_fabricante_referencia  \
# 1695228  PFIZER - PEDIÁTRICA MENOR DE 5 ANOS                         28290
# 1139646                     SINOVAC/BUTANTAN                           152
# 1197949  PFIZER - PEDIÁTRICA MENOR DE 5 ANOS                         28290
# 977036   PFIZER - PEDIÁTRICA MENOR DE 5 ANOS                         28290
# 591481   PFIZER - PEDIÁTRICA MENOR DE 5 ANOS                         28290
# ...                                      ...                           ...
# 1429293                     SINOVAC/BUTANTAN                           152
# 1009293                  ASTRAZENECA/FIOCRUZ                           NaN
# 715583                   ASTRAZENECA/FIOCRUZ                           NaN
# 1431741                  ASTRAZENECA/FIOCRUZ                           NaN
# 1391075                  ASTRAZENECA/FIOCRUZ                           NaN
#
#         vacina_dataAplicacao vacina_descricao_dose  vacina_codigo  \
# 1695228           2023-03-02               1ª Dose            102
# 1139646           2023-03-02               1ª Dose             86
# 1197949           2023-03-02               1ª Dose            102
# 977036            2023-03-02               1ª Dose            102
# 591481            2023-03-02               1ª Dose            102
# ...                      ...                   ...            ...
# 1429293           2021-01-17               1ª Dose             86
# 1009293           2021-01-02               1ª Dose             85
# 715583            2021-01-02               1ª Dose             85
# 1431741           2021-01-02               1ª Dose             85
# 1391075           2021-01-02               1ª Dose             85
#
#                                                vacina_nome  \
# 1695228  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# 1139646              COVID-19 SINOVAC/BUTANTAN - CORONAVAC
# 1197949  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# 977036   COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# 591481   COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# ...                                                    ...
# 1429293              COVID-19 SINOVAC/BUTANTAN - CORONAVAC
# 1009293          COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD
# 715583           COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD
# 1431741          COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD
# 1391075          COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD
#
#                         sistema_origem
# 1695228                       Novo PNI
# 1139646                       Novo PNI
# 1197949                       Novo PNI
# 977036                        Novo PNI
# 591481                        Novo PNI
# ...                                ...
# 1429293                       Novo PNI
# 1009293  ESUS APS - NACIONAL (OFFLINE)
# 715583   ESUS APS - NACIONAL (OFFLINE)
# 1431741  ESUS APS - NACIONAL (OFFLINE)
# 1391075  ESUS APS - NACIONAL (OFFLINE)
#
# [660104 rows x 32 columns]

# %%
# contar o número de doses por fabricante e por tipo de dose
dados_dose = dados.groupby(['vacina_fabricante_nome', 'vacina_descricao_dose'])['vacina_descricao_dose'].count()

# converter a série em um dataframe com colunas separadas para cada tipo de dose
dados_dose = dados_dose.unstack()

# exibir o resultado
dados_dose
# Out:
# vacina_descricao_dose                       1ª Dose  1ª Dose Revacinação  \
# vacina_fabricante_nome
# ASTRAZENECA                                  3225.0                  NaN
# ASTRAZENECA/FIOCRUZ                        257239.0                125.0
# FUNDACAO OSWALDO CRUZ                           NaN                  NaN
# JANSSEN                                       533.0                 37.0
# PFIZER                                     187453.0                294.0
# PFIZER - PEDI?TRICA                          6763.0                  NaN
# PFIZER - PEDIÁTRICA                          6233.0                169.0
# PFIZER - PEDIÁTRICA MENOR DE 5 ANOS          2285.0                  NaN
# PFIZER MANUFACTURING BELGIUM NV - BELGICA       NaN                  NaN
# Pendente Identifica??o                       3867.0                  NaN
# Pendente Identificação                      13331.0                  NaN
# SINOVAC                                       476.0                  NaN
# SINOVAC/BUTANTAN                           178699.0                 33.0
#
# vacina_descricao_dose                      1º Reforço   2ª Dose  \
# vacina_fabricante_nome
# ASTRAZENECA                                       NaN    1180.0
# ASTRAZENECA/FIOCRUZ                               2.0  238225.0
# FUNDACAO OSWALDO CRUZ                             NaN       NaN
# JANSSEN                                          18.0     816.0
# PFIZER                                           44.0  156293.0
# PFIZER - PEDI?TRICA                               NaN    5300.0
# PFIZER - PEDIÁTRICA                              41.0    6928.0
# PFIZER - PEDIÁTRICA MENOR DE 5 ANOS               NaN     214.0
# PFIZER MANUFACTURING BELGIUM NV - BELGICA         NaN       NaN
# Pendente Identifica??o                            NaN      96.0
# Pendente Identificação                            NaN    6478.0
# SINOVAC                                           NaN     945.0
# SINOVAC/BUTANTAN                                  3.0  145117.0
#
# vacina_descricao_dose                      2ª Dose Revacinação  2º Reforço  \
# vacina_fabricante_nome
# ASTRAZENECA                                                NaN         NaN
# ASTRAZENECA/FIOCRUZ                                      126.0     15847.0
# FUNDACAO OSWALDO CRUZ                                      NaN         1.0
# JANSSEN                                                   48.0     13239.0
# PFIZER                                                   109.0     19910.0
# PFIZER - PEDI?TRICA                                        NaN         NaN
# PFIZER - PEDIÁTRICA                                        2.0         NaN
# PFIZER - PEDIÁTRICA MENOR DE 5 ANOS                        NaN         NaN
# PFIZER MANUFACTURING BELGIUM NV - BELGICA                  NaN         2.0
# Pendente Identifica??o                                     NaN         NaN
# Pendente Identificação                                     NaN         2.0
# SINOVAC                                                    1.0         3.0
# SINOVAC/BUTANTAN                                           3.0       286.0
#
# vacina_descricao_dose                       3ª Dose  3ª Dose Revacinação  \
# vacina_fabricante_nome
# ASTRAZENECA                                     NaN                  4.0
# ASTRAZENECA/FIOCRUZ                         27267.0                105.0
# FUNDACAO OSWALDO CRUZ                           NaN                  NaN
# JANSSEN                                      3533.0                 46.0
# PFIZER                                     139310.0                247.0
# PFIZER - PEDI?TRICA                            36.0                  NaN
# PFIZER - PEDIÁTRICA                           722.0                  3.0
# PFIZER - PEDIÁTRICA MENOR DE 5 ANOS            25.0                  NaN
# PFIZER MANUFACTURING BELGIUM NV - BELGICA       NaN                  NaN
# Pendente Identifica??o                          2.0                  NaN
# Pendente Identificação                          2.0                  NaN
# SINOVAC                                         NaN                  NaN
# SINOVAC/BUTANTAN                              743.0                  2.0
#
# vacina_descricao_dose                      3º Reforço  4ª Dose  \
# vacina_fabricante_nome
# ASTRAZENECA                                       NaN      NaN
# ASTRAZENECA/FIOCRUZ                             108.0  17535.0
# FUNDACAO OSWALDO CRUZ                             NaN      NaN
# JANSSEN                                         160.0   1632.0
# PFIZER                                          189.0  69222.0
# PFIZER - PEDI?TRICA                               NaN     35.0
# PFIZER - PEDIÁTRICA                               NaN     20.0
# PFIZER - PEDIÁTRICA MENOR DE 5 ANOS               NaN      NaN
# PFIZER MANUFACTURING BELGIUM NV - BELGICA         NaN      NaN
# Pendente Identifica??o                            NaN      NaN
# Pendente Identificação                            NaN      2.0
# SINOVAC                                           NaN      NaN
# SINOVAC/BUTANTAN                                  7.0    520.0
#
# vacina_descricao_dose                      4ª Dose Revacinação  5ª Dose  \
# vacina_fabricante_nome
# ASTRAZENECA                                                7.0      NaN
# ASTRAZENECA/FIOCRUZ                                      185.0     67.0
# FUNDACAO OSWALDO CRUZ                                      NaN      NaN
# JANSSEN                                                  132.0     11.0
# PFIZER                                                   177.0    253.0
# PFIZER - PEDI?TRICA                                        NaN      NaN
# PFIZER - PEDIÁTRICA                                        NaN      1.0
# PFIZER - PEDIÁTRICA MENOR DE 5 ANOS                        NaN      NaN
# PFIZER MANUFACTURING BELGIUM NV - BELGICA                  NaN      NaN
# Pendente Identifica??o                                     NaN      NaN
# Pendente Identificação                                     NaN      NaN
# SINOVAC                                                    NaN      NaN
# SINOVAC/BUTANTAN                                           2.0      2.0
#
# vacina_descricao_dose                      5ª Dose Revacinação    Dose  \
# vacina_fabricante_nome
# ASTRAZENECA                                                NaN     NaN
# ASTRAZENECA/FIOCRUZ                                        1.0     NaN
# FUNDACAO OSWALDO CRUZ                                      NaN     NaN
# JANSSEN                                                    2.0  6530.0
# PFIZER                                                     1.0     2.0
# PFIZER - PEDI?TRICA                                        NaN     NaN
# PFIZER - PEDIÁTRICA                                        NaN     NaN
# PFIZER - PEDIÁTRICA MENOR DE 5 ANOS                        NaN     NaN
# PFIZER MANUFACTURING BELGIUM NV - BELGICA                  NaN     NaN
# Pendente Identifica??o                                     NaN     NaN
# Pendente Identificação                                     NaN     NaN
# SINOVAC                                                    NaN     NaN
# SINOVAC/BUTANTAN                                           NaN     3.0
#
# vacina_descricao_dose                      Dose Adicional   Reforço  \
# vacina_fabricante_nome
# ASTRAZENECA                                          99.0     405.0
# ASTRAZENECA/FIOCRUZ                                1465.0   40783.0
# FUNDACAO OSWALDO CRUZ                                 NaN       NaN
# JANSSEN                                             689.0   10092.0
# PFIZER                                             2047.0  100114.0
# PFIZER - PEDI?TRICA                                   NaN       NaN
# PFIZER - PEDIÁTRICA                                   NaN    1415.0
# PFIZER - PEDIÁTRICA MENOR DE 5 ANOS                   NaN       NaN
# PFIZER MANUFACTURING BELGIUM NV - BELGICA             NaN       2.0
# Pendente Identifica??o                                NaN       NaN
# Pendente Identificação                                9.0      34.0
# SINOVAC                                               NaN     168.0
# SINOVAC/BUTANTAN                                     37.0    4726.0
#
# vacina_descricao_dose                      Revacinação   Única
# vacina_fabricante_nome
# ASTRAZENECA                                        NaN     NaN
# ASTRAZENECA/FIOCRUZ                               45.0     NaN
# FUNDACAO OSWALDO CRUZ                              NaN     NaN
# JANSSEN                                           23.0  5224.0
# PFIZER                                            78.0     NaN
# PFIZER - PEDI?TRICA                                NaN     NaN
# PFIZER - PEDIÁTRICA                                5.0     NaN
# PFIZER - PEDIÁTRICA MENOR DE 5 ANOS                NaN     NaN
# PFIZER MANUFACTURING BELGIUM NV - BELGICA          NaN     NaN
# Pendente Identifica??o                             NaN     NaN
# Pendente Identificação                             NaN     NaN
# SINOVAC                                            NaN     NaN
# SINOVAC/BUTANTAN                                   3.0     NaN

# %% [markdown]
# # Tratamento dos dados

# %%
# Tratamento dos dados de fabricantes das vacinas

# substituir os nomes das fabricantes que deseja agrupar por um novo nome
dados['vacina_fabricante_nome'] = dados['vacina_fabricante_nome'].replace({
    'PFIZER - PEDIÁTRICA': 'PFIZER_PEDIÁTRICA', 
    'PFIZER - PEDIÁTRICA MENOR DE 5 ANOS': 'PFIZER_PEDIÁTRICA',
    'PFIZER - PEDI?TRICA': 'PFIZER_PEDIÁTRICA',
    'Pendente Identifica??o': 'Pendente Identificação',
    'Pendente Identifica??o': 'Pendente Identificação',
    'ASTRAZENECA/FIOCRUZ': 'ASTRAZENECA',
    'PFIZER MANUFACTURING BELGIUM NV - BELGICA': 'PFIZER',
    'SINOVAC/BUTANTAN': 'SINOVAC',
    'FUNDACAO OSWALDO CRUZ': 'ASTRAZENECA'})

# agrupar as quantidades por dose, considerando o novo nome das fabricantes
dados_dose = dados.groupby(['vacina_fabricante_nome', 'vacina_descricao_dose'])['vacina_descricao_dose'].count().unstack()

dados_dose
# Out:
# vacina_descricao_dose    1ª Dose  1ª Dose Revacinação  1º Reforço   2ª Dose  \
# vacina_fabricante_nome
# ASTRAZENECA             260464.0                125.0         2.0  239405.0
# JANSSEN                    533.0                 37.0        18.0     816.0
# PFIZER                  187453.0                294.0        44.0  156293.0
# PFIZER_PEDIÁTRICA        15281.0                169.0        41.0   12442.0
# Pendente Identificação   17198.0                  NaN         NaN    6574.0
# SINOVAC                 179175.0                 33.0         3.0  146062.0
#
# vacina_descricao_dose   2ª Dose Revacinação  2º Reforço   3ª Dose  \
# vacina_fabricante_nome
# ASTRAZENECA                           126.0     15848.0   27267.0
# JANSSEN                                48.0     13239.0    3533.0
# PFIZER                                109.0     19912.0  139310.0
# PFIZER_PEDIÁTRICA                       2.0         NaN     783.0
# Pendente Identificação                  NaN         2.0       4.0
# SINOVAC                                 4.0       289.0     743.0
#
# vacina_descricao_dose   3ª Dose Revacinação  3º Reforço  4ª Dose  \
# vacina_fabricante_nome
# ASTRAZENECA                           109.0       108.0  17535.0
# JANSSEN                                46.0       160.0   1632.0
# PFIZER                                247.0       189.0  69222.0
# PFIZER_PEDIÁTRICA                       3.0         NaN     55.0
# Pendente Identificação                  NaN         NaN      2.0
# SINOVAC                                 2.0         7.0    520.0
#
# vacina_descricao_dose   4ª Dose Revacinação  5ª Dose  5ª Dose Revacinação  \
# vacina_fabricante_nome
# ASTRAZENECA                           192.0     67.0                  1.0
# JANSSEN                               132.0     11.0                  2.0
# PFIZER                                177.0    253.0                  1.0
# PFIZER_PEDIÁTRICA                       NaN      1.0                  NaN
# Pendente Identificação                  NaN      NaN                  NaN
# SINOVAC                                 2.0      2.0                  NaN
#
# vacina_descricao_dose     Dose  Dose Adicional   Reforço  Revacinação   Única
# vacina_fabricante_nome
# ASTRAZENECA                NaN          1564.0   41188.0         45.0     NaN
# JANSSEN                 6530.0           689.0   10092.0         23.0  5224.0
# PFIZER                     2.0          2047.0  100116.0         78.0     NaN
# PFIZER_PEDIÁTRICA          NaN             NaN    1415.0          5.0     NaN
# Pendente Identificação     NaN             9.0      34.0          NaN     NaN
# SINOVAC                    3.0            37.0    4894.0          3.0     NaN

# %%
# agrupar as vacinas por dose
dados_dose['1ª Dose Total'] = dados_dose[['1ª Dose', '1ª Dose Revacinação', '1º Reforço']].sum(axis=1)
dados_dose['2ª Dose Total'] = dados_dose[['2ª Dose', '2ª Dose Revacinação', '2º Reforço']].sum(axis=1)

dados_dose
# Out:
# vacina_descricao_dose    1ª Dose  1ª Dose Revacinação  1º Reforço   2ª Dose  \
# vacina_fabricante_nome
# ASTRAZENECA             260464.0                125.0         2.0  239405.0
# JANSSEN                    533.0                 37.0        18.0     816.0
# PFIZER                  187453.0                294.0        44.0  156293.0
# PFIZER_PEDIÁTRICA        15281.0                169.0        41.0   12442.0
# Pendente Identificação   17198.0                  NaN         NaN    6574.0
# SINOVAC                 179175.0                 33.0         3.0  146062.0
#
# vacina_descricao_dose   2ª Dose Revacinação  2º Reforço   3ª Dose  \
# vacina_fabricante_nome
# ASTRAZENECA                           126.0     15848.0   27267.0
# JANSSEN                                48.0     13239.0    3533.0
# PFIZER                                109.0     19912.0  139310.0
# PFIZER_PEDIÁTRICA                       2.0         NaN     783.0
# Pendente Identificação                  NaN         2.0       4.0
# SINOVAC                                 4.0       289.0     743.0
#
# vacina_descricao_dose   3ª Dose Revacinação  3º Reforço  4ª Dose  \
# vacina_fabricante_nome
# ASTRAZENECA                           109.0       108.0  17535.0
# JANSSEN                                46.0       160.0   1632.0
# PFIZER                                247.0       189.0  69222.0
# PFIZER_PEDIÁTRICA                       3.0         NaN     55.0
# Pendente Identificação                  NaN         NaN      2.0
# SINOVAC                                 2.0         7.0    520.0
#
# vacina_descricao_dose   4ª Dose Revacinação  5ª Dose  5ª Dose Revacinação  \
# vacina_fabricante_nome
# ASTRAZENECA                           192.0     67.0                  1.0
# JANSSEN                               132.0     11.0                  2.0
# PFIZER                                177.0    253.0                  1.0
# PFIZER_PEDIÁTRICA                       NaN      1.0                  NaN
# Pendente Identificação                  NaN      NaN                  NaN
# SINOVAC                                 2.0      2.0                  NaN
#
# vacina_descricao_dose     Dose  Dose Adicional   Reforço  Revacinação   Única  \
# vacina_fabricante_nome
# ASTRAZENECA                NaN          1564.0   41188.0         45.0     NaN
# JANSSEN                 6530.0           689.0   10092.0         23.0  5224.0
# PFIZER                     2.0          2047.0  100116.0         78.0     NaN
# PFIZER_PEDIÁTRICA          NaN             NaN    1415.0          5.0     NaN
# Pendente Identificação     NaN             9.0      34.0          NaN     NaN
# SINOVAC                    3.0            37.0    4894.0          3.0     NaN
#
# vacina_descricao_dose   1ª Dose Total  2ª Dose Total
# vacina_fabricante_nome
# ASTRAZENECA                  260591.0       255379.0
# JANSSEN                         588.0        14103.0
# PFIZER                       187791.0       176314.0
# PFIZER_PEDIÁTRICA             15491.0        12444.0
# Pendente Identificação        17198.0         6576.0
# SINOVAC                      179211.0       146355.0

# %%
dict_fab = dados_dose.to_dict(orient='dict')
dict_fab
# Out:
# {'1ª Dose': {'ASTRAZENECA': 260464.0,
#   'JANSSEN': 533.0,
#   'PFIZER': 187453.0,
#   'PFIZER_PEDIÁTRICA': 15281.0,
#   'Pendente Identificação': 17198.0,
#   'SINOVAC': 179175.0},
#  '1ª Dose Revacinação': {'ASTRAZENECA': 125.0,
#   'JANSSEN': 37.0,
#   'PFIZER': 294.0,
#   'PFIZER_PEDIÁTRICA': 169.0,
#   'Pendente Identificação': nan,
#   'SINOVAC': 33.0},
#  '1º Reforço': {'ASTRAZENECA': 2.0,
#   'JANSSEN': 18.0,
#   'PFIZER': 44.0,
#   'PFIZER_PEDIÁTRICA': 41.0,
#   'Pendente Identificação': nan,
#   'SINOVAC': 3.0},
#  '2ª Dose': {'ASTRAZENECA': 239405.0,
#   'JANSSEN': 816.0,
#   'PFIZER': 156293.0,
#   'PFIZER_PEDIÁTRICA': 12442.0,
#   'Pendente Identificação': 6574.0,
#   'SINOVAC': 146062.0},
#  '2ª Dose Revacinação': {'ASTRAZENECA': 126.0,
#   'JANSSEN': 48.0,
#   'PFIZER': 109.0,
#   'PFIZER_PEDIÁTRICA': 2.0,
#   'Pendente Identificação': nan,
#   'SINOVAC': 4.0},
#  '2º Reforço': {'ASTRAZENECA': 15848.0,
#   'JANSSEN': 13239.0,
#   'PFIZER': 19912.0,
#   'PFIZER_PEDIÁTRICA': nan,
#   'Pendente Identificação': 2.0,
#   'SINOVAC': 289.0},
#  '3ª Dose': {'ASTRAZENECA': 27267.0,
#   'JANSSEN': 3533.0,
#   'PFIZER': 139310.0,
#   'PFIZER_PEDIÁTRICA': 783.0,
#   'Pendente Identificação': 4.0,
#   'SINOVAC': 743.0},
#  '3ª Dose Revacinação': {'ASTRAZENECA': 109.0,
#   'JANSSEN': 46.0,
#   'PFIZER': 247.0,
#   'PFIZER_PEDIÁTRICA': 3.0,
#   'Pendente Identificação': nan,
#   'SINOVAC': 2.0},
#  '3º Reforço': {'ASTRAZENECA': 108.0,
#   'JANSSEN': 160.0,
#   'PFIZER': 189.0,
#   'PFIZER_PEDIÁTRICA': nan,
#   'Pendente Identificação': nan,
#   'SINOVAC': 7.0},
#  '4ª Dose': {'ASTRAZENECA': 17535.0,
#   'JANSSEN': 1632.0,
#   'PFIZER': 69222.0,
#   'PFIZER_PEDIÁTRICA': 55.0,
#   'Pendente Identificação': 2.0,
#   'SINOVAC': 520.0},
#  '4ª Dose Revacinação': {'ASTRAZENECA': 192.0,
#   'JANSSEN': 132.0,
#   'PFIZER': 177.0,
#   'PFIZER_PEDIÁTRICA': nan,
#   'Pendente Identificação': nan,
#   'SINOVAC': 2.0},
#  '5ª Dose': {'ASTRAZENECA': 67.0,
#   'JANSSEN': 11.0,
#   'PFIZER': 253.0,
#   'PFIZER_PEDIÁTRICA': 1.0,
#   'Pendente Identificação': nan,
#   'SINOVAC': 2.0},
#  '5ª Dose Revacinação': {'ASTRAZENECA': 1.0,
#   'JANSSEN': 2.0,
#   'PFIZER': 1.0,
#   'PFIZER_PEDIÁTRICA': nan,
#   'Pendente Identificação': nan,
#   'SINOVAC': nan},
#  'Dose': {'ASTRAZENECA': nan,
#   'JANSSEN': 6530.0,
#   'PFIZER': 2.0,
#   'PFIZER_PEDIÁTRICA': nan,
#   'Pendente Identificação': nan,
#   'SINOVAC': 3.0},
#  'Dose Adicional': {'ASTRAZENECA': 1564.0,
#   'JANSSEN': 689.0,
#   'PFIZER': 2047.0,
#   'PFIZER_PEDIÁTRICA': nan,
#   'Pendente Identificação': 9.0,
#   'SINOVAC': 37.0},
#  'Reforço': {'ASTRAZENECA': 41188.0,
#   'JANSSEN': 10092.0,
#   'PFIZER': 100116.0,
#   'PFIZER_PEDIÁTRICA': 1415.0,
#   'Pendente Identificação': 34.0,
#   'SINOVAC': 4894.0},
#  'Revacinação': {'ASTRAZENECA': 45.0,
#   'JANSSEN': 23.0,
#   'PFIZER': 78.0,
#   'PFIZER_PEDIÁTRICA': 5.0,
#   'Pendente Identificação': nan,
#   'SINOVAC': 3.0},
#  'Única': {'ASTRAZENECA': nan,
#   'JANSSEN': 5224.0,
#   'PFIZER': nan,
#   'PFIZER_PEDIÁTRICA': nan,
#   'Pendente Identificação': nan,
#   'SINOVAC': nan},
#  '1ª Dose Total': {'ASTRAZENECA': 260591.0,
#   'JANSSEN': 588.0,
#   'PFIZER': 187791.0,
#   'PFIZER_PEDIÁTRICA': 15491.0,
#   'Pendente Identificação': 17198.0,
#   'SINOVAC': 179211.0},
#  '2ª Dose Total': {'ASTRAZENECA': 255379.0,
#   'JANSSEN': 14103.0,
#   'PFIZER': 176314.0,
#   'PFIZER_PEDIÁTRICA': 12444.0,
#   'Pendente Identificação': 6576.0,
#   'SINOVAC': 146355.0}}

# %%
# Manter apenas 1ª dose e 2ª dose
# Criação dos dataframes
p_dose = pd.DataFrame({ '1ª Dose Total': {'ASTRAZENECA': 260591.0,
  'JANSSEN': 588.0,
  'PFIZER': 187791.0,
  'PFIZER_PEDIÁTRICA': 15491.0,
  'Pendente Identificação': 17198.0,
  'SINOVAC': 179211.0}})

s_dose = pd.DataFrame({'2ª Dose Total': {'ASTRAZENECA': 255379.0,
  'JANSSEN': 14103.0,
  'PFIZER': 176314.0,
  'PFIZER_PEDIÁTRICA': 12444.0,
  'Pendente Identificação': 6576.0,
  'SINOVAC': 146355.0}})

# Mesclar os dois dataframes
dose_grup = pd.merge(p_dose, s_dose, left_index=True, right_index=True)

# Ordenar os valores pelo total de doses
dose_grup = dose_grup.sort_values(by=['1ª Dose Total'], ascending=False)
dose_grup
# Out:
#                         1ª Dose Total  2ª Dose Total
# ASTRAZENECA                  260591.0       255379.0
# PFIZER                       187791.0       176314.0
# SINOVAC                      179211.0       146355.0
# Pendente Identificação        17198.0         6576.0
# PFIZER_PEDIÁTRICA             15491.0        12444.0
# JANSSEN                         588.0        14103.0

# %%
# Criar gráfico de barras
sns.catplot(data=dose_grup, kind="bar", x="vacina_fabricante_nome", y="vacina_descricao_dose", hue="Vacinas")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Criar gráfico de barras
# ----> 2 sns.catplot(data=dose_grup, kind="bar", x="vacina_fabricante_nome", y="vacina_descricao_dose", hue="Vacinas")
#
# File ~\AppData\Roaming\Python\Python39\site-packages\seaborn\categorical.py:3187, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3185 p = _CategoricalPlotter()
#    3186 p.require_numeric = plotter_class.require_numeric
# -> 3187 p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3188 if (
#    3189     order is not None
#    3190     or (sharex and p.orient == "v")
#    3191     or (sharey and p.orient == "h")
#    3192 ):
#    3193     # Sync categorical axis between facets to have the same categories
#    3194     order = p.group_names
#
# File ~\AppData\Roaming\Python\Python39\site-packages\seaborn\categorical.py:541, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539     if isinstance(var, str):
#     540         err = f"Could not interpret input '{var}'"
# --> 541         raise ValueError(err)
#     543 # Figure out the plotting orientation
#     544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#
# ValueError: Could not interpret input 'vacina_fabricante_nome'

# %% [markdown]
# # Problema
# * Quais foram as vacinas mais utilizadas durante a 1ª e 2ª dose?

# %% [markdown]
# Conforme visto nos dados, no período de 02/01/21 - 02/03/23, as fabricantes de vacinas mais utilizadas na administração da 1ª e 2ª dose foram:
# 1) Astrazeneca
# 2) Pfizer
# 3) Sinovac
